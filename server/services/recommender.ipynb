# %%
import sys
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel

# %%
# lines = sys.stdin.readlines()

# movie_id = lines[0]
# movie_data = lines[1]

movie_data = [
  {
    "_id": "656bf7480f722b2ed396cc16",
    "name": "Nhất Niệm Quan Sơn",
    "trailerCode": "qNNtYro5Ihw",
    "id": "https://ophim1.com/phim/nhat-niem-quan-son",
    "backdrop_path": "https://firebasestorage.googleapis.com/v0/b/twtcinema.appspot.com/o/images%2FNhat-Niem-Quan-Son-1-01.jpg?alt=media&token=aaeca708-13c2-4723-94b4-46694cc98445",
    "poster_path": "https://firebasestorage.googleapis.com/v0/b/twtcinema.appspot.com/o/images%2Funnamed.jpg?alt=media&token=0637b969-d056-4d2c-a799-2d734f844716",
    "genres": [
      "122"
    ],
    "category": "tv",
    "releaseDate": "2023-12-03",
    "ibmPoints": 6.7,
    "country": "Trung Quốc",
    "overview": "Hai sát thủ hàng đầu từ các cơ quan đối thủ và nhóm sáu thành viên của họ có xuất thân đa dạng và kỹ năng độc đáo bắt tay vào một cuộc hành trình đầy thử thách và khủng hoảng.",
    "seasons": 1,
    "episodes": 14,
    "viewed": 49,
    "createdAt": "2023-12-03T03:34:32.436Z",
    "updatedAt": "2023-12-09T13:29:46.467Z",
    "slug": "nhat-niem-quan-son",
    "__v": 0
  },
  {
    "_id": "656c0b3d0f722b2ed396d16a",
    "name": "Mùa hè cuối cùng",
    "trailerCode": "62uj_F8_FLc",
    "id": "https://ophim1.com/phim/mua-he-cuoi-cung",
    "backdrop_path": "https://firebasestorage.googleapis.com/v0/b/twtcinema.appspot.com/o/images%2Ft%E1%BA%A3i%20xu%E1%BB%91ng%20(1).jpg?alt=media&token=06a068ff-86bc-4144-81f3-119e538e155a",
    "poster_path": "https://firebasestorage.googleapis.com/v0/b/twtcinema.appspot.com/o/images%2Fv_114495964_m_601_m2_260_360.jpg?alt=media&token=2f4d79bd-05aa-4d63-8fa4-20cc3c0c21d3",
    "genres": [
      "122"
    ],
    "category": "movie",
    "releaseDate": "2023-11-03",
    "ibmPoints": 7,
    "country": "Viet nam",
    "overview": "Mùa hè cuối cùng",
    "episodes": 0,
    "viewed": 2,
    "createdAt": "2023-12-03T04:59:41.880Z",
    "updatedAt": "2023-12-06T14:53:11.572Z",
    "slug": "mua-he-cuoi-cung",
    "__v": 0,
    "seasons": 1
  },
  {
    "_id": "65707bb1627c350f490bf5d7",
    "name": "Đấu Phá Thương Khung: Thức Tỉnh",
    "trailerCode": "X1NQUqwNnCQ",
    "id": "https://ophim1.com/phim/dau-pha-thuong-khung-thuc-tinh",
    "backdrop_path": "https://firebasestorage.googleapis.com/v0/b/twtcinema.appspot.com/o/images%2Fdau-pha-thuong-khung-thuc-tinh-poster.jpg?alt=media&token=73aacb45-f8c2-4dfc-9abe-e7df786d1869",
    "poster_path": "https://firebasestorage.googleapis.com/v0/b/twtcinema.appspot.com/o/images%2Fdau-pha-thuong-khung-thuc-tinh-thumb.jpg?alt=media&token=c9d6b4ab-3f2c-4a09-9be0-3f564502c50f",
    "genres": [
      "436271",
      "123456"
    ],
    "category": "movie",
    "releaseDate": "2023-12-06",
    "ibmPoints": 5,
    "country": "Trung Quốc",
    "overview": "Tiêu Viêm (Mã Bá Khiên đóng) là con trai thứ ba của một trong ba gia tộc lớn nhất thành Ô Thản, vì đấu khí không cao mà trở thành trò cười của mọi người. Khi bị đại đệ tử của Vân Lam Tông là Nạp Lan Yên Nhiên (Cận Dương Dương đóng) hủy hôn, Tiêu Viêm không chịu được sự sỉ nhục đã lập ra giao hẹn ba năm với Yên Nhiên, ba năm sau sẽ tỷ thí để quyết định hôn ước. Để nâng cao đấu khí, Tiêu Viêm đã đến rặng núi ma thú, kết bạn với Tiểu Y Tiên (Từ Y đóng), nhưng rồi cũng bị vướng vào trận tranh chấp của binh đoàn Đầu Sói. Khi trốn chạy sự truy đuổi của binh đoàn Đầu Sói, Tiêu Viêm đã vô tình bắt gặp Đấu hoàng Vân Chi (Hồ Tĩnh đóng) và Dực sư vương Tử Tinh đang giao đấu với nhau. Vân Chi không thể đánh bại Dực sư, Tiêu Viêm đã cứu Vân Chi. Sau một vài biến cố, hai người quyết định đi thách đấu Dực sư một lần nữa. Hai người chia nhau ra hành động, sau cùng giành thắng lợi. Vân Chi âm thầm rời đi, Tiêu Viêm cũng quyết định rời khỏi rặng núi ma thú, hướng đến sa mạc của Xà tộc....",
    "seasons": 1,
    "episodes": 0,
    "viewed": 1,
    "createdAt": "2023-12-06T13:48:33.751Z",
    "updatedAt": "2023-12-06T14:44:46.268Z",
    "slug": "dau-pha-thuong-khung-thuc-tinh",
    "__v": 0
  },
  {
    "_id": "65708ffe627c350f490bf8f3",
    "name": "Cuộc Hôn Nhân Thứ Ba",
    "trailerCode": "YxHu0vYjQFE",
    "id": "https://ophim1.com/phim/cuoc-hon-nhan-thu-ba",
    "backdrop_path": "https://firebasestorage.googleapis.com/v0/b/twtcinema.appspot.com/o/images%2Fcuoc-hon-nhan-thu-ba-poster.jpg?alt=media&token=19db9223-e2c8-4624-8b23-ac8091921164",
    "poster_path": "https://firebasestorage.googleapis.com/v0/b/twtcinema.appspot.com/o/images%2Fcuoc-hon-nhan-thu-ba-thumb.jpg?alt=media&token=ee6dde0d-ed81-4e34-bfeb-3400162ae470",
    "genres": [
      "122"
    ],
    "category": "movie",
    "releaseDate": "2023-12-06",
    "ibmPoints": 8,
    "country": "Hàn Quốc",
    "overview": "Cuộc Hôn Nhân Thứ Ba 2023 VietSub - The Third Marriage 2023 là một bức tranh tinh thần đầy màu sắc, mô tả cuộc hành trình của Kim Min Hee, một phụ nữ trẻ đối diện với những thử thách và bi kịch đầy khắc nghiệt của cuộc đời.</p><p>Min Hee (do diễn viên nổi tiếng đảm nhận) là một người phụ nữ thông minh và quyết đoán. Nhưng số phận đã đưa cô vào tình huống khó khăn khi cô em gái Ji Soo gặp tai nạn nghiêm trọng và cần một cuộc phẫu thuật cấp cứu đắt đỏ để sống sót. Để cứu lấy em gái, Min Hee đã đồng ý kết hôn với Joon Ho (do một diễn viên tài năng đóng), một người đàn ông giàu có và quyền lực, mặc cho tình cảm thực sự của cô.</p><p>Nhưng bi kịch chưa dừng lại ở đó. Ji Soo mất mạng trong một tai nạn bí ẩn, để lại Min Hee đau khổ và hối hận. Sự thất bại này đánh thức một khao khát trả thù đẫy mê hoặc trong tâm hồn cô. Min Hee quyết định bước vào cuộc hôn nhân thứ ba không phải với mục tiêu xây dựng một mái ấm gia đình, mà để tìm ra sự thật đằng sau cái chết của em gái mình.</p><p>Tuy nhiên, cuộc sống trong ngôi nhà mới với người chồng mới không hề êm đềm. Min Hee phải đối mặt với những âm mưu, thù địch và những bí mật đen tối mà cô không thể ngờ tới. Cuộc hôn nhân trở thành một cuộc chiến đấu không khoan nhượng, và Min Hee phải sử dụng tất cả sự thông minh và sức mạnh của mình để đối mặt với những thách thức khó khăn.</p><p>Cuộc Hôn Nhân Thứ Ba 2023 VietSub - The Third Marriage 2023 là một tác phẩm điện ảnh đậm chất con người. Bên cạnh diễn xuất xuất sắc của các diễn viên, bộ phim chạm đến những khía cạnh nhức nhối của cuộc sống và trái tim con người. Nó là một câu chuyện về tình yêu, sự hy sinh, và trả thù trong một thế giới đầy bi kịch. Cùng với sự căng thẳng, hấp dẫn và đầy xúc động, bộ phim chắc chắn sẽ gợi lại nhiều cảm xúc trong lòng khán giả. Hãy cùng khám phá cuộc hành trình đầy oan trái và bí ẩn này khi \\\"Cuộc Hôn Nhân Thứ Ba\\\" ra mắt.",
    "episodes": "null",
    "viewed": 1,
    "createdAt": "2023-12-06T15:15:10.433Z",
    "updatedAt": "2023-12-06T15:15:39.507Z",
    "slug": "cuoc-hon-nhan-thu-ba",
    "__v": 0
  }
]

# %%
# Convert JSON data to DataFrame
movies = pd.DataFrame(movie_data)
# Combine relevant information into a feature representation for each movie
movies['combined_features'] = movies.apply(lambda row: ' '.join(row['genres']) + ' ' + row['country'], axis=1)

# Create a feature representation for each movie using TF-IDF
tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(movies['combined_features'])

# Compute the cosine similarity between movies based on their features
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

print(cosine_sim)
# Out:
# [[1.         0.21908734 0.49331813 0.50466766]
#  [0.21908734 1.         0.         0.1949127 ]
#  [0.49331813 0.         1.         0.17376622]
#  [0.50466766 0.1949127  0.17376622 1.        ]]

# %%
# Function to get movie recommendations based on item ID
def get_recommendations(item_id, cosine_sim=cosine_sim):
    idx = movies.index[movies['_id'] == item_id].tolist()[0]
    filter_scores = []
    sim_scores = list(enumerate(cosine_sim[idx]))
    for score in sim_scores:
        if score[1] > 0:
            filter_scores.append(score)
    filter_scores = sorted(filter_scores, key=lambda x: x[1], reverse=True)
    filter_scores = filter_scores[0:10]  # Lấy 10 mục tương tự
    item_indices = [i[0] for i in filter_scores]
    item_ids = movies['_id'].iloc[item_indices].tolist()
    # Sử dụng list comprehension để tìm các đối tượng tương ứng
    items = [item for item in movie_data if item['_id'] in item_ids if item['_id'] != item_id]
    return items

# Get movie recommendations for a specific movie ID (replace with your desired movie ID)
movie_id = "656bf7480f722b2ed396cc16"
recommendations = get_recommendations(movie_id)

# Display the recommendations
print(f"\nTop 5 Movie Recommendations for Movie ID {movie_id}:\n")
for item in recommendations:
    print(item['name'], "\n")
# Out:
# ['65708ffe627c350f490bf8f3', '65707bb1627c350f490bf5d7', '656c0b3d0f722b2ed396d16a']
#
# Top 5 Movie Recommendations for Movie ID 656bf7480f722b2ed396cc16:
#
# Mùa hè cuối cùng
#
# Đấu Phá Thương Khung: Thức Tỉnh
#
# Cuộc Hôn Nhân Thứ Ba
